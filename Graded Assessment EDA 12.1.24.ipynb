# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"H:\data analysis\Kaggle\Instruction and Dataset-20240112\Life Expectancy Data.csv")

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2922 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult mortality                  2928 non-null   float64
#  5   Infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   Percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  Under-five deaths                2938 non-null   int64
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy  Adult mortality  Infant deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  Percentage expenditure  Hepatitis B        Measles  \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                              16
# Life expectancy                     10
# Adult mortality                     10
# Infant deaths                        0
# Alcohol                            194
# Percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# Under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                           0
# Thinness  1-19 years                34
# Thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.value_counts('Country')
# Out:
# Country
# Afghanistan              16
# Peru                     16
# Nicaragua                16
# Niger                    16
# Nigeria                  16
#                          ..
# Palau                     1
# Niue                      1
# Nauru                     1
# Saint Kitts and Nevis     1
# Dominica                  1
# Name: count, Length: 193, dtype: int64

# %%
df.value_counts('Status')
# Out:
# Status
# Developing    2413
# Developed      509
# Name: count, dtype: int64

# %%
df.loc[df.Status.isnull()]
# Out:
#                   Country  Year Status  Life expectancy  Adult mortality  \
# 6             Afghanistan  2009    NaN             58.6            281.0
# 15            Afghanistan  2000    NaN             54.8            321.0
# 27                Albania  2004    NaN             73.0             17.0
# 46                Algeria  2001    NaN             71.4            145.0
# 65    Antigua and Barbuda  2014    NaN             76.2            131.0
# 75    Antigua and Barbuda  2004    NaN             74.4            149.0
# 82              Argentina  2013    NaN             76.0            119.0
# 93              Argentina  2002    NaN             74.1            138.0
# 104               Armenia  2007    NaN             73.5            132.0
# 118             Australia  2009    NaN             81.7             66.0
# 136               Austria  2007    NaN             81.0              8.0
# 148            Azerbaijan  2011    NaN             71.6            125.0
# ...

# %%
df.loc[df.Status.isnull(),["Status"]] = "Developing"

# %%
df.loc[(df.Status.isnull()) & (df["Country"] == "Australia"),["Status"]] = "Developed"

# %%
df.loc[(df.Status.isnull()) & ( df.Country == "Austria"),["Status"]] = "Developed"

# %%
df.loc[(df.Status.isnull()) & (df.Country == "Portugual"),["Status"]] = "Developed"

# %%
df.loc[df["Population"] =="#"]["Country"].value_counts()
# Out:
# Country
# Antigua and Barbuda                                     16
# Singapore                                               16
# New Zealand                                             16
# Oman                                                    16
# Qatar                                                   16
# Republic of Korea                                       16
# Republic of Moldova                                     16
# Saint Lucia                                             16
# Saint Vincent and the Grenadines                        16
# Saudi Arabia                                            16
# Slovakia                                                16
# Libya                                                   16
# Somalia                                                 16
# The former Yugoslav republic of Macedonia               16
# United Arab Emirates                                    16
# United Kingdom of Great Britain and Northern Ireland    16
# ...

# %%
ndf = df.select_dtypes(include=["int64","float64"])
ndf
# Out:
#       Year  Life expectancy  Adult mortality  Infant deaths  Alcohol  \
# 0     2015             65.0            263.0             62     0.01
# 1     2014             59.9            271.0             64     0.01
# 2     2013             59.9            268.0             66     0.01
# 3     2012             59.5            272.0             69     0.01
# 4     2011             59.2            275.0             71     0.01
# ...    ...              ...              ...            ...      ...
# 2933  2004             44.3            723.0             27     4.36
# 2934  2003             44.5            715.0             26     4.06
# 2935  2002             44.8             73.0             25     4.43
# 2936  2001             45.3            686.0             25     1.72
# 2937  2000             46.0            665.0             24     1.68
#
#       Percentage expenditure  Hepatitis B  Measles   BMI  Under-five deaths  \
# ...

# %%
cdf = df.select_dtypes(include="object")
cdf
# Out:
#           Country      Status Population
# 0     Afghanistan  Developing   33736494
# 1     Afghanistan  Developing     327582
# 2     Afghanistan  Developing   31731688
# 3     Afghanistan  Developing    3696958
# 4     Afghanistan  Developing    2978599
# ...           ...         ...        ...
# 2933     Zimbabwe  Developing   12777511
# 2934     Zimbabwe  Developing   12633897
# 2935     Zimbabwe  Developing     125525
# 2936     Zimbabwe  Developing   12366165
# 2937     Zimbabwe  Developing   12222251
#
# [2938 rows x 3 columns]

# %%
ndf.corr()
# Out:
#                                      Year  Life expectancy  Adult mortality  \
# Year                             1.000000         0.170033        -0.079052
# Life expectancy                  0.170033         1.000000        -0.696359
# Adult mortality                 -0.079052        -0.696359         1.000000
# Infant deaths                   -0.037415        -0.196557         0.078756
# Alcohol                         -0.052990         0.404877        -0.195848
# Percentage expenditure           0.031400         0.381864        -0.242860
# Hepatitis B                      0.104333         0.256762        -0.162476
# Measles                         -0.082493        -0.157586         0.031176
# BMI                              0.108974         0.567694        -0.387017
# Under-five deaths               -0.042937        -0.222529         0.094146
# Polio                            0.094158         0.465556        -0.274823
# ...

# %% [markdown]
# alcohol has mild positive relation with life expectancy (which could mean since they live long so drink for a longer time)
# too many insights let focus on big ones:-
# education increases life expectancy(highly +ive related)
# LifeExpectancy = BMI,polio,diptheria,hiv,gdp,thinness1to19 is a mildfactor;;; incresourcesand schooling has high relation
# Adultmortality = hiv,schooling,incresorces are mildly related
# infantdeaths = measeles,thines1to19
# alcohol = bmi,thinness1to19,income,schooling
# percentageexp = gdp strongly
# hepB = polio,diptheria
# measeles = infant,under5
# bmi = lifewxp,thinness1to19,income , schooling mild
# under5 = thinness mild related
# polio= lifeexpectancy,hepB, mild , dipheria highly
# totalexp =
# diptheria = hepB,polio .06 related .04 study,incomeresource
# hiv = LE,AM,
# gdp = percentage exp ,life exp

# %%
c = df.loc[df["Life expectancy"].isnull(),"Country"]
c # san marino look into it
#dfc = []
#dfc = pd.DataFrame(dfc)
#for i in c:
#    dfc = dfc.add(df[df.Country == i])
# Out:
# 624              Cook Islands
# 769                  Dominica
# 1650         Marshall Islands
# 1715                   Monaco
# 1812                    Nauru
# 1909                     Niue
# 1958                    Palau
# 2167    Saint Kitts and Nevis
# 2216               San Marino
# 2713                   Tuvalu
# Name: Country, dtype: object

# %%
df.loc[df["Life expectancy"].isnull()]
# Out:
#                     Country  Year      Status  Life expectancy  \
# 624            Cook Islands  2013  Developing              NaN
# 769                Dominica  2013  Developing              NaN
# 1650       Marshall Islands  2013  Developing              NaN
# 1715                 Monaco  2013  Developing              NaN
# 1812                  Nauru  2013  Developing              NaN
# 1909                   Niue  2013  Developing              NaN
# 1958                  Palau  2013  Developing              NaN
# 2167  Saint Kitts and Nevis  2013  Developing              NaN
# 2216             San Marino  2013  Developing              NaN
# 2713                 Tuvalu  2013  Developing              NaN
#
#       Adult mortality  Infant deaths  Alcohol  Percentage expenditure  \
# 624               NaN              0     0.01                0.000000
# 769               NaN              0     0.01               11.419555
# ...

# %%
df = df.dropna(subset=["Life expectancy"])

# %%
df.loc[df["Adult mortality"].isnull()] #taken care with above
# Out:
# Empty DataFrame
# Columns: [Country, Year, Status, Life expectancy, Adult mortality, Infant deaths, Alcohol, Percentage expenditure, Hepatitis B, Measles, BMI, Under-five deaths, Polio, Total expenditure, Diphtheria, HIV/AIDS, GDP, Population, Thinness  1-19 years, Thinness 5-9 years, Income composition of resources, Schooling]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.loc[df["Alcohol"].isnull()]
# Out:
#                                  Country  Year      Status  Life expectancy  \
# 32                               Algeria  2015  Developing             75.6
# 48                                Angola  2015  Developing             52.4
# 64                   Antigua and Barbuda  2015  Developing             76.4
# 80                             Argentina  2015  Developing             76.3
# 96                               Armenia  2015  Developing             74.8
# ...                                  ...   ...         ...              ...
# 2858  Venezuela (Bolivarian Republic of)  2015  Developing             74.1
# 2874                            Viet Nam  2015  Developing             76.0
# 2890                               Yemen  2015  Developing             65.7
# 2906                              Zambia  2015  Developing             61.8
# 2922                            Zimbabwe  2015  Developing             67.0
#
# ...

# %%
df.loc[df.Alcohol.isnull(),"Alcohol"] = 4.60

# %%
df.loc[df["Alcohol"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Status, Life expectancy, Adult mortality, Infant deaths, Alcohol, Percentage expenditure, Hepatitis B, Measles, BMI, Under-five deaths, Polio, Total expenditure, Diphtheria, HIV/AIDS, GDP, Population, Thinness  1-19 years, Thinness 5-9 years, Income composition of resources, Schooling]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.loc[df["Income composition of resources"].isnull()]
# Out:
#                        Country  Year      Status  Life expectancy  \
# 432              Côte d'Ivoire  2015  Developing             53.3
# 433              Côte d'Ivoire  2014  Developing             52.8
# 434              Côte d'Ivoire  2013  Developing             52.3
# 435              Côte d'Ivoire  2012  Developing             52.0
# 436              Côte d'Ivoire  2011  Developing             51.7
# ...                        ...   ...         ...              ...
# 2805  United States of America  2004   Developed             77.5
# 2806  United States of America  2003   Developed             77.2
# 2807  United States of America  2002   Developed             77.0
# 2808  United States of America  2001   Developed             76.9
# 2809  United States of America  2000   Developed             76.8
#
#       Adult mortality  Infant deaths  Alcohol  Percentage expenditure  \
# 432             397.0             57     4.60                     0.0
# ...

# %%
df.loc[df.Schooling.isnull(),"Schooling"] = 11.992793

# %%
df.loc[df["Income composition of resources"].isnull(),"Income composition of resources"] = 0.627551

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                      0
# Adult mortality                      0
# Infant deaths                        0
# Alcohol                              0
# Percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 32
# Under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                443
# Population                           0
# Thinness  1-19 years                32
# Thinness 5-9 years                  32
# Income composition of resources      0
# Schooling                            0
# dtype: int64
